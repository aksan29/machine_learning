# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sklearn.linear_model as ln
# using jupyter notebook theme
import jupyterthemes.jtplot as jt
jt.style(theme='gruvboxd')

# %%
df = pd.read_fwf('brain_body.txt')
df
# Out:
#       Brain   Body
# 0     3.385   44.5
# 1     0.480   15.5
# 2     1.350    8.1
# 3   465.000  423.0
# 4    36.330  119.5
# ..      ...    ...
# 57  160.000  169.0
# 58    0.900    2.6
# 59    1.620   11.4
# 60    0.104    2.5
# 61    4.235   50.4
#
# [62 rows x 2 columns]

# %%
_brain = df[['Brain']]
_body = np.array(df['Body'])

# %%
# visualization 
plt.figure (figsize=[18,13])
plt.scatter(_brain,_body,s=140)
plt.xlabel('Brain')
plt.ylabel('Body')
plt.xlim(0,700)
plt.ylim(0,700)
# Out:
# (0, 700)

# %%
x_0 = np.array(df['Brain'])
den = x_0.dot(x_0) - x_0.mean() * x_0.sum()
slope = (x_0.dot(_body)-_body.mean()*x_0.sum())/den
intercept =(_body.mean()*x_0.dot(x_0)-x_0.mean()*x_0.dot(_body))/den
data1 = np.array([3500]) 
predict = slope*x_0+ intercept
print(slope)
print(intercept)
# Out:
# 0.9664963676725763
# 91.0043962074068

# %%
# visualization 
plt.figure (figsize=[18,13])
plt.scatter(_brain,_body,s=140)
plt.plot(_brain,predict,color ='red',lineWidth =4)
plt.xlabel('Brain')
plt.ylabel('Body')
plt.xlim(0,700)
plt.ylim(0,700)
plt.show()

# %%
# example 2

x1 = np.array([17,13,12,15,16,14,16,16,18,19])
y1 = np.array([94,73,59,80,93,85,66,79,77,91])


den1 = x1.dot(x1)-x1.mean()*x1.sum()
slope1=( x1.dot(y1) - y1.mean()*x1.sum()) / den1
intercept1 = (y1.mean()*x1.dot(x1)-x1.mean()*x1.dot(y1))/den1
p1 = np.array([15])
predict1 = intercept1 + slope1*x1
print(slope1)
print(intercept1)
print(predict1)
# Out:
# 3.179245283018844
# 30.103773584906143
# [84.1509434  71.43396226 68.25471698 77.79245283 80.97169811 74.61320755
#  80.97169811 80.97169811 87.33018868 90.50943396]

# %%
plt.figure(figsize=[15,9])
plt.scatter(x1,y1,color ='red',s=140)
plt.plot(x1,predict1)
