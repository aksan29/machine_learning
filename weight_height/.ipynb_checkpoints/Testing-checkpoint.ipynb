# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import jupyterthemes.jtplot as jt
import sklearn.linear_model as ln
import csv
import math
jt.style(theme='gruvboxd')

# %% [markdown]
# ### Step1 (explore data and visualization)

# %%
df=pd.read_csv('weight-height.csv')
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
# Gender    10000 non-null object
# Height    10000 non-null float64
# Weight    10000 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
df['Gender'].value_counts()
# Out:
# Female    5000
# Male      5000
# Name: Gender, dtype: int64

# %%
# visualise based on the gender
males =df[df['Gender']=='Male']
females =df[df['Gender']=='Female']
plt.figure(figsize=[15,9])
plt.scatter(males['Height'],males['Weight'],color ='blue',label='male')
plt.scatter(females['Height'],females['Weight'],color ='red',label='female')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# visualise based on the weight and the height up to average value
males_height= (males['Height'])
females_height= (females['Height'])
males_weight= (males['Weight'])
females_weight= (females['Weight'])
plt.figure(figsize=[10,19])
plt.subplot(2,1,1)
plt.hist([females_height,males_height],color=['green','red'],label=['female','male'])
plt.xlabel('Number of people')
plt.ylabel('Height')
plt.legend()
plt.subplot(2,1,2)
plt.hist([females_weight,males_weight],color=['green','red'],label=['female','male'])
plt.xlabel('Number of people')
plt.ylabel('Weight')
plt.legend()
plt.show()

# %% [markdown]
# ## Step2 Initially and Calculate loss function

# %%
# Calculate with scikit learn
reg= ln.LinearRegression()

y1 = np.array(df['Weight']).reshape(10000,1)
x1 = np.array(df['Height']).reshape(10000,1)
reg.fit(x1,y1)
reg.coef_
reg.intercept_

males =df[df['Gender']=='Male']
females =df[df['Gender']=='Female']
plt.figure(figsize=[15,9])
plt.scatter(males['Height'],males['Weight'],color ='blue',label='male')
plt.scatter(females['Height'],females['Weight'],color ='red',label='female')
plt.plot(df['Height'],reg.predict(x1),color ='green',lineWidth=4)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print('''
from the scikit learn we get
''')
print('the slope is ',reg.coef_)
print('the intercept is',reg.intercept_)
# Out:
# from the scikit learn we get
#
# the slope is  [[7.71728764]]
# the intercept is [-350.73719181]

# %%
# calculate based on build mode
m = 0
c = 0
L= 0.0001

n= float(len(df['Weight']))
y = np.array(df['Weight'])
x = np.array(df['Height'])

for i in range(len(y)):
    y_predict = m*x+c
    d_c = -2/n * sum(y-y_predict)
    d_m = (-2/n) *sum(x*(y-y_predict))
    # update value of m and value of c
    m = m-(L*d_m)
    c= c-(L*d_c)
y_predict = m*x+c
plt.figure(figsize=[15,9])
plt.scatter(males['Height'],males['Weight'],color ='blue',label='male')
plt.scatter(females['Height'],females['Weight'],color ='red',label='female')
plt.plot(df['Height'],y_predict,color='green',lineWidth = 4)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print('''
from the building model we can get 
''')
print('the slope is ',m)
print('the intercept is',c)
# Out:
# from the building model we can get
#
# the slope is  2.484822538216764
# the intercept is -2.3045159664543537

# %% [markdown]
# ### model 3

# %%
y3 = np.array(df['Weight'])
x3 = np.array(df['Height'])
den = x3.dot(x3) - x3.mean() * x3.sum()
slope3 = (x3.dot(y3)-y3.mean()*x3.sum())/den
intercept3 =(y3.mean()*x3.dot(x3)-x3.mean()*x3.dot(y3))/den
predict3 = slope3*x3+ intercept3
plt.figure(figsize=[15,9])
plt.scatter(males['Height'],males['Weight'],color ='blue',label='male')
plt.scatter(females['Height'],females['Weight'],color ='red',label='female')
plt.plot(df['Height'],predict3,color ='green',lineWidth=4)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print('''
from the building model we can get 
''')
print('the slope is ',slope3)
print('the intercept is',intercept3)
# Out:
# from the building model we can get
#
# the slope is  7.717287640785149
# the intercept is -350.7371918121224
